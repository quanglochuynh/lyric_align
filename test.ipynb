# %%
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
# import os
# import wave
# from scipy.io import wavfile
import tensorflow_io as tfio
# Out:
# /Users/lochuynhquang/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/Users/lochuynhquang/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ["[Errno 2] The file to load file system plugin from does not exist.: '/Users/lochuynhquang/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so'"]
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /Users/lochuynhquang/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/Users/lochuynhquang/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# ...

# %%
def load_wav(path):
    file = tf.io.read_file(path)
    wave, samplerate = tf.audio.decode_wav(file, desired_channels=1)
    wave = tf.squeeze(wave, axis=-1)
    samplerate = tf.cast(samplerate, dtype=tf.int64)
    wave = tfio.resample(wave, rate_in=samplerate, rate_out=16000)

# %%
# wav = wave.open("data/37303137375f3131.wav", 'r')
# for i in range(wav.getnframes()):
#     frame = wav.readframes(i)
#     print (frame)

# samplerate, data = wavfile.read('data/37303137375f3131.wav')
# print(samplerate)
# print(np.shape(data))

bdbg = load_wav('data/37303137375f3131.wav')
plt.plot(bdbg)
plt.show()
# Out:
# 2022-11-19 12:14:13.923775: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-19 12:14:13.924519: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/lochuynhquang/Documents/lyric_align/test.ipynb Cell 3 in <cell line: 10>()
# ...

# %%
length = data.shape[0] / samplerate
time = np.linspace(0., length, data.shape[0])
plt.plot(time, data[:, 0], label="Left channel")
plt.plot(time, data[:, 1], label="Right channel")
plt.legend()
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.show()
